# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import TimeSeriesSplit, train_test_split

# %%
train_df = pd.read_csv("/content/drive/My Drive/Hackathon/Grocery_sales/Train.csv")
train_df.head()
# Out:
#    Day  GrocerySales
# 0    1       8418.59
# 1    2       8447.47
# 2    3       8336.49
# 3    4       8579.17
# 4    5       8524.31

# %%
test_df = pd.read_csv("/content/drive/My Drive/Hackathon/Grocery_sales/Test.csv")
test_df.head()
# Out:
#    Day
# 0  693
# 1  694
# 2  695
# 3  696
# 4  697

# %%
train_df.describe()
# Out:
#               Day  GrocerySales
# count  692.000000    692.000000
# mean   346.500000   8564.733471
# std    199.907479    428.815668
# min      1.000000   6766.370000
# 25%    173.750000   8411.536858
# 50%    346.500000   8677.770000
# 75%    519.250000   8852.387500
# max    692.000000   9290.020000

# %%
plt.figure(figsize=(30,10))
plt.plot(train_df['GrocerySales'], color='r')
plt.xlabel('Days', fontsize=(40))
plt.ylabel('Sales', fontsize=(40))
plt.show()
